# %% [markdown]
# <a href="https://colab.research.google.com/github/rfortuna98/QNC-Fall-2025/blob/main/Binomial_ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from chat gpt exercice 1
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters
n = 10       # number of quanta
p = 0.2      # probability of release per quantum

# Possible outcomes: 0 to 10 quanta released
k_values = list(range(n + 1))
probabilities = binom.pmf(k_values, n, p)

# Display probabilities
for k, prob in zip(k_values, probabilities):
    print(f"P({k} quanta released) = {prob:.4f}")

# Optional: plot the distribution
plt.bar(k_values, probabilities, color='skyblue', edgecolor='black')
plt.title('Binomial Distribution of Quanta Release')
plt.xlabel('Number of Quanta Released')
plt.ylabel('Probability')
plt.xticks(k_values)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# P(0 quanta released) = 0.1074
# P(1 quanta released) = 0.2684
# P(2 quanta released) = 0.3020
# P(3 quanta released) = 0.2013
# P(4 quanta released) = 0.0881
# P(5 quanta released) = 0.0264
# P(6 quanta released) = 0.0055
# P(7 quanta released) = 0.0008
# P(8 quanta released) = 0.0001
# P(9 quanta released) = 0.0000
# P(10 quanta released) = 0.0000
